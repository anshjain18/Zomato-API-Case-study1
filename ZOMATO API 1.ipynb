# %% [markdown]
# ## ZOMATO API
# For this project, we are using the Zomato API.
# Zomato APIs give you access to the freshest and most exhaustive information for over 1.5 million restaurants across 10,000 cities globally.
# Zomato API documentation link
# Our Motivation for using Zomato API
# By Collecting the data using Zomato API one can recommend restaurants on the basis of user’s affinity to specific cuisines, establishment types, locations, and price bands.
# We can find out whether restaurant support online reservation or not.
# We can find what is the most popular and/ or exclusive/new at a given location & time.

# %% [markdown]
# ## ZOMATO CUISINE PROBLEMS

# %%
#1. Fetch the cuisine_id of ‘Mexican’ cuisine using Zomato API. Print the cuisine_id.
#SOURCE CODE
import requests
import json
resp=requests.get("https://developers.zomato.com/api/v2.1/cities",params={"q":"Mexico"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
# print(data)
resp1=requests.get("https://developers.zomato.com/api/v2.1/cuisines",params={"city_id":"1"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
data2=resp1.json()
for i in data2["cuisines"]:
    if i["cuisine"]["cuisine_name"]=="Mexican":
        print(i["cuisine"]["cuisine_id"])

#efc6f149ec2ca6b1d7941e9a7cbb0625 . THIS IS MY UNIQUE API KEY
# Out:
# 73

# %%
#2. Fetch the entityid and entitytype of place Connaught Place. Print the entityid and entitytype.


import requests
import json
resp=requests.get("https://developers.zomato.com/api/v2.1/cities",params={"q":"Mexico"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
# print(data)
resp1=requests.get("https://developers.zomato.com/api/v2.1/locations",params={"query":"Connaught Place"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
data2=resp1.json()
print(data2["location_suggestions"][0]["entity_type"],data2["location_suggestions"][0]["entity_id"])
#efc6f149ec2ca6b1d7941e9a7cbb0625

# %%
#3. Fetch the top 10 best-rated restaurant serving ‘Mexican’ cuisine present in Connaught Place.
#Print the restaurant name, user rating and restaurant id.


import requests
import json
import numpy
resp=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"entity_id":"104","entity_type":"subzone","cuisines":"73"
                      ,"sort":"rating","order":"desc","count":10,"start":0},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})

# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
# data1=resp1.json()
# data2=resp2.json()
name=[]
rating=[]
id=[]
c=0
for i in data["restaurants"]:
    # if "Mexican" in i["restaurant"]["cuisines"]:
    name.append(i["restaurant"]["name"])
    rating.append(i["restaurant"]["user_rating"]["aggregate_rating"])
    id.append(i["restaurant"]["id"])


lis1=numpy.argsort(rating)

for i in range(len(name)):
    print(name[i],rating[i],id[i])

# %%
#4. Fetch the category id of category type ‘Cafes’ using Zomato API. Print the category_id.

import requests
import json
resp=requests.get("https://developers.zomato.com/api/v2.1/cities",params={"q":"Mexico"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
# print(data)
resp1=requests.get("https://developers.zomato.com/api/v2.1/categories",headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
data2=resp1.json()
# print(data2)
for i in data2["categories"]:

        if i["categories"]["name"]== "Cafes":
            print(i["categories"]["id"])

# %% [markdown]
# ## ZOMATO RESTURANT PROBLEMS

# %%
#5. Fetch the best-rated restaurant for ‘Mexican’ cuisine with category type ‘ Cafes’ present in
#Connaught Place using Zomato API.
#Print the restaurant name, user rating and restaurant id


#3a1a2e50ab0a85b8c3d085c64ba849bd
import requests
import json
import numpy
resp=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"entity_id":"104","entity_type":"subzone","cuisines":"73","count":10,"start":0,
                          "sort":"rating","order":"desc",
                          "category":"6"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
resp1=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"entity_id":"104","entity_type":"subzone","cuisines":"73","count":100,"start":20,
                          "category":"6"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
resp2=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"entity_id":"104","entity_type":"subzone","cuisines":"73"
                   ,"category":"6","count":100,"start":40},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
data1=resp1.json()
data2=resp2.json()
name=[]
rating=[]
id=[]
c=0
# print(data)
for i in data["restaurants"]:
    print(i["restaurant"]["name"],i["restaurant"]["user_rating"]["aggregate_rating"],i["restaurant"]["id"])

# %%
#6.Fetch the latest review of the best-rated restaurant for ‘Mexican’ cuisine with Category type 
#‘Cafes’ present in Connaught Place using Zomato API.
#Print the name of user ,user rating and review text.


import requests
import json
import numpy
resp=requests.get("https://developers.zomato.com/api/v2.1/reviews",
                  params={"res_id":18241537},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
resp1=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"entity_id":"104","entity_type":"subzone","cuisines":"73","count":100,"start":20,
                          "category":"6"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
resp2=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"entity_id":"104","entity_type":"subzone","cuisines":"73"
                   ,"category":"6","count":100,"start":40},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
data1=resp1.json()
data2=resp2.json()
name=[]
rating=[]
id=[]
c=0
# print(data)
for i in data["user_reviews"]:
        print(i["review"]["user"]["name"],i["review"]["rating"],i["review"]["review_text"])

# %%
#7. Fetch the details of restaurant 736 AD using Zomato API.
#Print the user rating, average cost for two, cuisines and address of 736 AD.

#3a1a2e50ab0a85b8c3d085c64ba849bd
import requests
import json
resp=requests.get("https://developers.zomato.com/api/v2.1/search",params={"q":"736 AD"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
# print(data)
resp1=requests.get("https://developers.zomato.com/api/v2.1/categories",headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
data2=resp1.json()
# print(data)
for i in data["restaurants"]:
    if i["restaurant"]["name"] == "736 A.D.":
        print(i["restaurant"]["user_rating"]["aggregate_rating"])
        print(i["restaurant"]["average_cost_for_two"])
        print(i["restaurant"]["cuisines"])
        print(i["restaurant"]["location"]["address"])
        break
#efc6f149ec2ca6b1d7941e9a7cbb0625
# print(4.3)
# print(1400)
# print("North Indian, Continental, Italian, Chinese, Momos")
# print("G-15/B, Vijay Nagar, New Delhi")

# %%
#8. Fetch the latest review of restaurant 736 AD using Zomato API.
# Print the name of user ,user rating and review text.


import requests
import json
import numpy
resp=requests.get("https://developers.zomato.com/api/v2.1/reviews",
                  params={"res_id":18241524},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
resp1=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"entity_id":"104","entity_type":"subzone","cuisines":"73","count":100,"start":20,
                          "category":"6"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
resp2=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"entity_id":"104","entity_type":"subzone","cuisines":"73"
                   ,"category":"6","count":100,"start":40},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
data1=resp1.json()
data2=resp2.json()
name=[]
rating=[]
id=[]
c=0
# print(data)
for i in data["user_reviews"]:
        print(i["review"]["user"]["name"],i["review"]["rating"],i["review"]["review_text"])

# %% [markdown]
# ## ZOMATO DISTANCE PROBLEMS

# %%
#9.Fetch the list of the top 10 restaurants serving cuisine ‘BBQ’ which are nearest to Coding Ninjas.
# Print the restaurant name, user rating, restaurant id and locality in which restaurant is present.


import requests
import json
import numpy
resp=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"cuisines":"193","lat":28.697513,"lon":77.1384332,"sort":"real_distance"
                      ,"order":"asc","count":10,"start":0},
                  headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})

# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
# data1=resp1.json()
# data2=resp2.json()
# print(data)
for i in data["restaurants"]:
    print(i["restaurant"]["name"],i["restaurant"]["user_rating"]["aggregate_rating"],
          i["restaurant"]["id"],i["restaurant"]["location"]["locality"])

# %%
#10. Fetch the latest review of the restaurant serving cuisine ‘BBQ’ which is most nearest to Coding ninjas?
# Print the name of user ,user rating and review text.



import requests
import json
import numpy
resp=requests.get("https://developers.zomato.com/api/v2.1/reviews",
                  params={"res_id":18204820},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
resp1=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"entity_id":"104","entity_type":"subzone","cuisines":"73","count":100,"start":20,
                          "category":"6"},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
resp2=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"entity_id":"104","entity_type":"subzone","cuisines":"73"
                   ,"category":"6","count":100,"start":40},headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})
# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
data1=resp1.json()
data2=resp2.json()
name=[]
rating=[]
id=[]
c=0
# print(data)
for i in data["user_reviews"]:
        print(i["review"]["user"]["name"],i["review"]["rating"],i["review"]["review_text"])

# %%
#11. Experiment with the radius parameter that is present in ‘GET/search’. 
# Fetch the list of top 10 best-restaurant present in a radius of 4 km of coding ninjas.
# Print the restaurant name, user rating, restaurant id and locality in which restaurant is present.


import requests
import json
import numpy
resp=requests.get("https://developers.zomato.com/api/v2.1/search",
                  params={"radius":4000,"lat":28.697513,"lon":77.1384332,"sort":"rating"
                      ,"order":"desc","count":10,"start":0},
                  headers={"user-key":"efc6f149ec2ca6b1d7941e9a7cbb0625"})

# print(resp.status_code)
# print(resp.url)
data=json.loads(resp.text)
# data1=resp1.json()
# data2=resp2.json()
# print(data)
for i in data["restaurants"]:
    print(i["restaurant"]["name"],i["restaurant"]["user_rating"]["aggregate_rating"],
          i["restaurant"]["id"],i["restaurant"]["location"]["locality"])
